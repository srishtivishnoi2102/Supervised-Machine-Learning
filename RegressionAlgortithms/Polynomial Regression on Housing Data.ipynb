# %% [markdown]
# ## importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output
import math

# %% [markdown]
# ## we are reading our californina housing price dataset in file "housing.cvs" using read_csv() method of pandas

# %%
data =pd.read_csv("datasets/housing.csv")

print("data.shape : \n",data.shape)

data.head()
# Out:
# data.shape :
#  (20640, 10)
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# # Data Cleaning
# ##  making sure that our data is icluding only those features which are having integer or float as datatype
# ### we do so by using pandas' select_dtypes() method.

# %%
data=data.select_dtypes(include=('float64','int64'))

# %% [markdown]
# ### now we have removed 'ocean_proximity' feature from our data successively

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0

# %%
data.shape
# Out:
# (20640, 9)

# %% [markdown]
# # Data Normalisation
# ## Here we are doing standard normalisation by subtraction data by mean and dividing it with standard deviation so that our data can be standardised with mean=0 and std=1

# %%
print("Before Normalisation: \n")
print("data.mean(): ",np.array(data.mean()))
print("data.std(): ",np.array(data.std()))

data =(data -data.mean())/data.std()

print("\n After Normalisation: \n")
print("data.mean(): ",np.array(data.mean()))
print("data.std(): ",np.array(data.std()))
# Out:
# Before Normalisation:
#
# data.mean():  [-1.19569704e+02  3.56318614e+01  2.86394864e+01  2.63576308e+03
#   5.37870553e+02  1.42547674e+03  4.99539680e+02  3.87067100e+00
#   2.06855817e+05]
# data.std():  [2.00353172e+00 2.13595240e+00 1.25855576e+01 2.18161525e+03
#  4.21385070e+02 1.13246212e+03 3.82329753e+02 1.89982172e+00
#  1.15395616e+05]
#
#  After Normalisation:
#
# data.mean():  [-1.42921497e-12 -7.63668091e-14  1.81739851e-15 -9.59080199e-17
#  -1.99180520e-16 -2.83652839e-16  7.56386502e-17 -2.52380965e-14
#   3.76787318e-16]
# data.std():  [1. 1. 1. 1. 1. 1. 1. 1. 1.]

# %% [markdown]
# # making sure that our data is not having any NaN value
# ### check which feature is having NaN values with pandas.isna() method

# %%
data.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
#so here we find that 203 rows are there that are having NaN value in "total_bedrooms" feature
# we will drop those rows by dropna() method with axis=0 i.e., row-wise.

data=data.dropna(axis=0)

# %%
data.shape
# Out:
# (20433, 9)

# %% [markdown]
# ## splitting data into X (features) and Y (target_variable)

# %%
X=data.drop('median_house_value',axis=1).copy()
Y=data['median_house_value']

# %% [markdown]
# ## splitting of data into training and testing

# %% [markdown]
# ### writing train_split_data

# %%
def train_test_split(X,Y,test_size=0.25,train_size=.75):
    
    train_size=1-test_size
    
    x_train=np.array(X[: int(train_size*X.shape[0])])
    x_test=np.array(X[ int(train_size*X.shape[0]):])
    
    y_train=Y[: int(train_size*len(Y))]
    y_train=np.array(y_train)
    y_train=y_train.reshape(len(y_train),1)
    
    y_test=Y[int(train_size*len(Y)):]
    y_test=np.array(y_test)
    y_test=y_test.reshape(len(y_test),1)
    
    return x_train,x_test,y_train,y_test

# %% [markdown]
# ## In Polynomial Regression, we raise the power of features.

# %% [markdown]
# ### making a list having powers of the features.

# %%
power_list=[i+1 for i in range(X.shape[1])]
power_list
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
X_temp=X.copy()
for i in range(len(power_list)):
    X_temp.iloc[:,i]=X_temp.iloc[:,i]**power_list[i]

# %%
X_temp.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0  -1.327803  1.107804            0.947310     0.419518       -0.860069
# 1  -1.322812  1.088181           -0.223653    17.518105        4.454929
# 2  -1.332794  1.078436            6.394841     0.082375       -0.383436
# 3  -1.337785  1.078436            6.394841     0.151808       -0.191818
# 4  -1.337785  1.078436            6.394841     0.045713       -0.085825
#
#    population  households  median_income
# 0    0.855928   -0.849749   9.135063e+02
# 1    0.408586   36.213517   8.751827e+02
# 2    0.305696   -0.304099   1.019861e+02
# 3    0.202025   -0.114523   5.739155e-01
# 4    0.192439   -0.039016   7.577246e-16

# %%
X.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0  -1.327803  1.052523            0.982119    -0.804800       -0.970301
# 1  -1.322812  1.043159           -0.607004     2.045841        1.348243
# 2  -1.332794  1.038478            1.856137    -0.535733       -0.825541
# 3  -1.337785  1.038478            1.856137    -0.624199       -0.718750
# 4  -1.337785  1.038478            1.856137    -0.462393       -0.611959
#
#    population  households  median_income
# 0   -0.974405   -0.977009       2.344709
# 1    0.861418    1.669921       2.332181
# 2   -0.820757   -0.843616       1.782656
# 3   -0.766010   -0.733764       0.932945
# 4   -0.759828   -0.629142      -0.012881

# %% [markdown]
# ## splitting X,Y into training testing part using train_test_split()

# %%
x_train,x_test,y_train,y_test=train_test_split(X_temp,Y)

# %% [markdown]
# # initiallising the weights and bias from standard normal distribution

# %%
weights0=np.random.rand(X.shape[1],1)
bias0=np.random.rand(1,1)

# %%
def curve(m,x,c):
    return (np.matmul(x,m)+c)
def error(m,x,c,y):
    return (np.mean((curve(m,x,x)-y)**2))

def derivative_wrt_weights(m,x,c,y):
    derivatives=2*(np.mean(np.multiply(x,curve(m,x,c)-y),axis=0))
    derivatives= np.array(derivatives)
    derivatives=derivatives.reshape(x.shape[1],1)
    return derivatives
     

def derivative_wrt_bias(m,x,c,y):
    return (2*np.mean(curve(m,x,c)-y)) 

def scalar(x):
    return (x-np.mean(x))/np.std(x)

def accuracy(error,y):
    return (1 -error/np.sum(y**2))*100

# %%
def model_result(alpha,num_of_iteration):
    weights=weights0
    bias=bias0
    lr=[]
    error_cost=[]
    for i in range(num_of_iteration):
        #alpha=alpha /((1.0085 )**i)
       # alpha =alpha*(i+.9) *.0005
        
      #  alpha=alpha/(1.01 + (i%100)*.00001) 
    
        alpha =math.pow(alpha,1.0005)*.00001 if i%500==0 and 1>10 else math.pow(alpha,1.0005)
        
        weights = weights - alpha * derivative_wrt_weights(weights,x_train,bias,y_train)
        bias = bias - alpha * derivative_wrt_bias(weights,x_train,bias,y_train)
        
        error_cost.append(error(weights,x_train,bias,y_train))
        print("Error is: ",error_cost[i])
        lr.append(alpha)
    print("lr func")
    plt.plot(lr)
    plt.show()
    print("cost func")
    plt.plot(error_cost)
    print("Accuracy is: ",accuracy(error_cost[-1],y_train))
    print("At endError is: ",error(weights,x_train,bias,y_train))

# %%
.0000000000001/(1.015)**150
# Out:
# 1.071750420592843e-14

# %%
 model_result(alpha=.0000000000000000025,num_of_iteration=1000)
# Out:
# Error is:  38333491647042.875
# Error is:  38322582200337.7
# Error is:  38311895684019.56
# Error is:  38301427572833.83
# Error is:  38291173434273.555
# Error is:  38281128926601.51
# Error is:  38271289796918.55
# Error is:  38261651879276.32
# Error is:  38252211092833.734
# Error is:  38242963440055.45
# Error is:  38233905004952.11
# Error is:  38225031951360.23
# Error is:  38216340521261.68
# Error is:  38207827033141.04
# Error is:  38199487880380.18
# Error is:  38191319529689.09
# Error is:  38183318519572.01
# Error is:  38175481458827.836
# Error is:  38167805025084.26
# Error is:  38160285963364.36
# Error is:  38152921084685.24
# Error is:  38145707264687.71
# Error is:  38138641442296.17
# Error is:  38131720618408.21
# Error is:  38124941854612.8
# Error is:  38118302271936.96
# Error is:  38111799049619.445
# Error is:  38105429423911.5
# Error is:  38099190686903.63
# Error is:  38093080185377.8
# Error is:  38087095319684.59
# Error is:  38081233542644.625
# Error is:  38075492358473.62
# Error is:  38069869321730.61
# Error is:  38064362036288.8
# Error is:  38058968154328.38
# Error is:  38053685375350.95
# Error is:  38048511445214.91
# Error is:  38043444155191.38
# Error is:  38038481341040.26
# Error is:  38033620882105.805
# Error is:  38028860700431.336
# Error is:  38024198759892.69
# Error is:  38019633065349.85
# Error is:  38015161661816.6
# Error is:  38010782633647.336
# Error is:  38006494103741.26
# Error is:  38002294232762.95
# Error is:  37998181218379.26
# Error is:  37994153294512.414
# Error is:  37990208730608.13
# Error is:  37986345830919.42
# Error is:  37982562933805.16
# Error is:  37978858411042.875
# Error is:  37975230667156.19
# Error is:  37971678138755.86
# Error is:  37968199293894.57
# Error is:  37964792631434.88
# Error is:  37961456680430.27
# Error is:  37958189999518.9
# Error is:  37954991176329.75
# Error is:  37951858826900.914
# Error is:  37948791595109.945
# Error is:  37945788152115.64
# Error is:  37942847195811.33
# Error is:  37939967450289.266
# Error is:  37937147665316.04
# Error is:  37934386615818.5
# Error is:  37931683101380.125
# Error is:  37929035945747.86
# Error is:  37926443996348.57
# Error is:  37923906123815.64
# Error is:  37921421221524.94
# Error is:  37918988205140.25
# Error is:  37916606012167.8
# Error is:  37914273601519.9
# Error is:  37911989953087.31
# Error is:  37909754067320.27
# Error is:  37907564964817.77
# Error is:  37905421685925.41
# Error is:  37903323290340.99
# Error is:  37901268856728.35
# Error is:  37899257482338.67
# Error is:  37897288282639.55
# Error is:  37895360390951.445
# Error is:  37893472958091.37
# Error is:  37891625152023.8
# Error is:  37889816157518.5
# Error is:  37888045175815.164
# Error is:  37886311424294.83
# Error is:  37884614136157.8
# Error is:  37882952560107.92
# Error is:  37881325960043.445
# Error is:  37879733614753.625
# Error is:  37878174817621.695
# Error is:  37876648876333.6
# Error is:  37875155112592.56
# Error is:  37873692861839.41
# Error is:  37872261472978.24
# Error is:  37870860308107.87
# Error is:  37869488742258.27
# Error is:  37868146163132.484
# Error is:  37866831970853.56
# Error is:  37865545577716.63
# Error is:  37864286407945.65
# Error is:  37863053897455.23
# Error is:  37861847493617.16
# Error is:  37860666655031.305
# Error is:  37859510851301.43
# Error is:  37858379562815.18
# Error is:  37857272280528.45
# Error is:  37856188505754.25
# Error is:  37855127749955.414
# Error is:  37854089534541.75
# Error is:  37807317858422.586
# Error is:  37807317857538.1
# Error is:  37807317856678.43
# Error is:  37807317855842.875
# Error is:  37807317855030.78
# Error is:  37807317854241.46
# Error is:  37807317853474.34
# Error is:  37807317852728.78
# Error is:  37807317852004.19
# Error is:  37807317851299.984
# Error is:  37807317850615.59
# Error is:  37807317849950.484
# Error is:  37807317849304.11
# Error is:  37807317848675.98
# Error is:  37807317848065.55
# Error is:  37807317847472.336
# Error is:  37807317846895.89
# Error is:  37807317846335.734
# Error is:  37807317845791.39
# Error is:  37807317845262.45
# Error is:  37807317844748.45
# Error is:  37807317844249.03
# Error is:  37807317843763.75
# Error is:  37807317843292.2
# Error is:  37807317842834.02
# Error is:  37807317842388.86
# Error is:  37807317841956.28
# Error is:  37807317841536.016
# Error is:  37807317841127.69
# Error is:  37807317840730.95
# Error is:  37807317840345.5
# Error is:  37807317839971.01
# Error is:  37807317839607.18
# Error is:  37807317839253.7
# Error is:  37807317838910.3
# Error is:  37807317838576.68
# Error is:  37807317838252.56
# Error is:  37807317837937.72
# Error is:  37807317837631.85
# Error is:  37807317837334.7
# Error is:  37807317837046.06
# Error is:  37807317836765.664
# Error is:  37807317836493.28
# Error is:  37807317836228.7
# Error is:  37807317835971.695
# Error is:  37807317835722.05
# Error is:  37807317835479.55
# Error is:  37807317835244.0
# Error is:  37807317835015.2
# Error is:  37807317834792.97
# Error is:  37807317834577.14
# Error is:  37807317834367.49
# Error is:  37807317834163.875
# Error is:  37807317833966.12
# Error is:  37807317833774.04
# Error is:  37807317833587.484
# Error is:  37807317833406.31
# Error is:  37807317833230.36
# Error is:  37807317833059.484
# Error is:  37807317832893.53
# Error is:  37807317832732.36
# Error is:  37807317832575.84
# Error is:  37807317832423.86
# Error is:  37807317832276.26
# Error is:  37807317832132.92
# Error is:  37807317831993.72
# Error is:  37807317831858.57
# Error is:  37807317831727.31
# Error is:  37807317831599.87
# Error is:  37807317831476.12
# Error is:  37807317831355.945
# Error is:  37807317831239.27
# Error is:  37807317831125.984
# Error is:  37807317831015.98
# Error is:  37807317830909.17
# Error is:  37807317830805.47
# Error is:  37807317830704.78
# Error is:  37807317830607.02
# Error is:  37807317830512.1
# Error is:  37807317830419.96
# Error is:  37807317830330.516
# Error is:  37807317830243.66
# Error is:  37807317830159.33
# Error is:  37807317830077.48
# Error is:  37807317829998.01
# Error is:  37807317829920.86
# Error is:  37807317829845.97
# Error is:  37807317829773.266
# Error is:  37807317829702.67
# Error is:  37807317829634.164
# Error is:  37807317829567.664
# Error is:  37807317829503.1
# Error is:  37807317829440.445
# Error is:  37807317829379.61
# Error is:  37807317829320.57
# Error is:  37807317829263.266
# Error is:  37807317829207.64
# Error is:  37807317829153.64
# Error is:  37807317829101.24
# Error is:  37807317829050.37
# Error is:  37807317829001.016
# Error is:  37807317828953.11
# Error is:  37807317828906.59
# Error is:  37807317828861.47
# Error is:  37807317828817.66
# Error is:  37807317828775.16
# Error is:  37807317828733.9
# Error is:  37807317828693.86
# Error is:  37807317828655.01
# Error is:  37807317828617.305
# Error is:  37807317828580.71
# Error is:  37807317828545.195
# Error is:  37807317828510.74
